# %% [markdown]
# Notebook to take excel spreadsheet and output at correctly encoded TSV for use in the web frontend.

# %%
import pandas as pd

# %%
df = pd.read_excel("archives.xlsx")

# %%
# Save as UTF-8 TSV
df.to_csv('archives.txt', sep='\t', encoding='utf-8', index=False)
